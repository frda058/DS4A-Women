# %%
import numpy as np
import pandas as pd
import opendatasets as od

# %% [markdown]
# # Download CDC Dataset from Kaggle

# %%
od.download("https://www.kaggle.com/datasets/francescaabulencia/cdc-brfss-survey-2020")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: francescaabulencia
# Your Kaggle Key: ········
#   2%|▏         | 1.00M/45.1M [00:00<00:07, 6.36MB/s]
# ...
# 100%|██████████| 45.1M/45.1M [00:04<00:00, 11.6MB/s]
